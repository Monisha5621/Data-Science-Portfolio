# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha5621/Data-Science-Portfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pdfminer

# %%
import os
from pdfminer.high_level import extract_text

# Define the path to the folder containing the PDF files
pdf_folder = "/content/drive/MyDrive/Cases"

# Create an empty list to store the text content of each PDF file
pdf_texts = []

# Iterate through each PDF file in the folder
for filename in os.listdir(pdf_folder):
    if filename.endswith(".pdf"):
        # Extract the text content from the PDF file using PDFMiner
        pdf_text = extract_text(os.path.join(pdf_folder, filename))
        # Append the text content to the list of PDF texts
        pdf_texts.append(pdf_text)

# %%
pdf_process_texts = pdf_texts

# %%
# !python -m spacy download en_core_web_lg
# Out:
# 2023-04-24 07:31:30.500799: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 07:31:31.561273: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.6 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy
from collections import Counter
from string import punctuation

nlp = spacy.load("en_core_web_lg")

import en_core_web_lg
nlp = en_core_web_lg.load()

def top_sentence(text, limit):

    keyword = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN', 'VERB']
    doc = nlp(text.lower()) #1
    for token in doc: #2
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue #3
        if(token.pos_ in pos_tag):
            keyword.append(token.text) #4

    freq_word = Counter(keyword) #5
    max_freq = Counter(keyword).most_common(1)[0][1] #6
    for w in freq_word:
        freq_word[w] = (freq_word[w]/max_freq) #7
    sent_strength={}
    for sent in doc.sents: #8
        for word in sent: #9
            if word.text in freq_word.keys(): #10
                if sent in sent_strength.keys():
                    sent_strength[sent]+=freq_word[word.text]#11
                else:
                    sent_strength[sent]=freq_word[word.text]#12

    summary = []
    sorted_x = sorted(sent_strength.items(), key=lambda kv: kv[1], reverse=True) #13

    counter = 0
    for i in range(len(sorted_x)): #14
        summary.append(str(sorted_x[i][0]).capitalize()) #15
        counter += 1
        if(counter >= limit):
            break #16

    return ' '.join(summary) #17

# List of documents
documents = pdf_texts

# Initialize an empty list to store summaries
summaries = []

# Loop over each document and call the top_sentence function
for doc in documents:
    summary = top_sentence(doc, 2)
    summaries.append(summary)

# Print the list of summaries
print("List of summaries:")
print(summaries)
# Out:
# List of summaries:
# ...

# %%
summaries
# Out:
# ["Child  welfare: \n\nchildren  engaged in  circuses - protection,  from  physical  c \n\nand sexual abuse - held:  government of india is fully aware \nabout the  problems  of children  working  in  various  places, \nparticularly,  in  circuses  - right  of children  to  free  and \ncompulsory  education  has  been  made  a  fundamental  right \nunder article 21-a  of the constitution - directions given  to  the  o \ncentral  government to  issue  suitable  notifications prohibiting \nemployment  of children  in  circuses  within  two  months  -\nfurther directions  issued  to  conduct simultaneous  raids  in  all \nthe  circuses  to  liberate  the  children  and check  the  violation \nof their  fundamental  rights  and  to  take  steps  for  their  e \nrehabilitation - the  secretary of ministry of human resources \ndevelopment,  department of women  and child development \ndirected  to  file  a  comprehensive  affidavit  of compliance  -\ncourt also  accepted  the  submission  a
# ...

# %%
import nltk
import re
import string
from nltk.corpus import stopwords, brown
from nltk.tokenize import word_tokenize, sent_tokenize, RegexpTokenizer
from nltk.stem import WordNetLemmatizer

# %%
def preprocess_text(text):
    '''Cleans text data up, leaving only 2 or more char long non-stepwords composed of A-Z & a-z only
    in lowercase'''

    # Convert text to lowercase
    text = text.lower()


    # Remove RT
    text = re.sub('RT @\w+: '," ", text)

    # Remove special characters
    text = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", text)

    # Single character removal
    text = re.sub(r"\s+[a-zA-Z]\s+", ' ', text)

    # Remove multiple spaces
    text = re.sub(r'\s+', ' ', text)

    return text

# %%
summary_list = []
for text in summaries:
    # apply preprocessing steps to text

    cleaned_text = preprocess_text(text)
    # add cleaned text to cleaned_list

    summary_list.append(cleaned_text)

# %%
summary_list
# Out:
# ['child welfare children engaged in circuses protection from physical and sexual abuse held government of india is fully aware about the problems of children working in various places particularly in circuses right of children to free and compulsory education has been made fundamental right under article 21 of the constitution directions given to the central government to issue suitable notifications prohibiting employment of children in circuses within two months further directions issued to conduct simultaneous raids in all the circuses to liberate the children and check the violation of their fundamental rights and to take steps for their rehabilitation the secretary of ministry of human resources development department of women and child development directed to file comprehensive affidavit of compliance court also accepted the submission and recommendations of the solicitor general of india each state should issue circular indicating how the recommendations will be implemented co
# ...

# %%
import pandas as pd

# %%
summary_list_final_df = pd.DataFrame(summary_list)

# %%
summary_list_final_df

# %%
summary_list_final_df.to_csv('/content/drive/My Drive/summary_list_250.csv', encoding='utf-8', index=False)  #summary_list_250

# %%
cleaned_list = []
for text in pdf_process_texts:
    # apply preprocessing steps to text

    cleaned_text = preprocess_text(text)
    # add cleaned text to cleaned_list

    cleaned_list.append(cleaned_text)

# %%
cleaned_list
# Out:
#                                                      0
# 0     2011 5 c 353 bachpan bachao andolan union of ...
# 1    34 ba 3184 of 2021 doc in the high court of ju...
# 2    in the high court of orissa at cuttack ablapl ...
# 3    1 igh court of chhattisgarh bilaspur mcrc no 1...
# 4    in the high court of jharkhand at ranchi crimi...
# ..                                                 ...
# 245  in the high court of judicature at patna crimi...
# 246  misc application with a no 7449 of 2019 in bai...
# 247  in the high court of jharkhand at ranchi a no ...
# 248  in the high court of judicature at patna crimi...
# 249  1 7 23 ba 1543 19 odt in the high court of jud...
#
# [250 rows x 1 columns]

# %%
cleaned_list_final_df = pd.DataFrame(cleaned_list)

# %%
cleaned_list_final_df

# %%
cleaned_list_final_df.to_csv('/content/drive/My Drive/cleaned_list_250.csv', encoding='utf-8', index=False) #cleaned_list_250

# %%
import pandas as pd

# %%
summary_list = pd.read_csv('/content/drive/My Drive/summary_list_250.csv')

# %%
cleaned_list = pd.read_csv('/content/drive/My Drive/cleaned_list_250.csv')

# %% [markdown]
# Cosine Similarity: This metric measures the similarity between the generated summary and the original text. It calculates the cosine of the angle between the vectors representing the generated summary and the original text.

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer object
vectorizer = CountVectorizer()

# Fit and transform the sentences
sentence_vectors = vectorizer.fit_transform([sentence_1, sentence_2])

# Compute cosine similarity
cosine_similarities = cosine_similarity(sentence_vectors)

# Extract cosine similarity score between sentence_1 and sentence_2
cosine_similarity_score = cosine_similarities[0][1]

# Print cosine similarity score
print("Cosine Similarity: {:.2f}".format(cosine_similarity_score))
# Out:
# Cosine Similarity: 0.83

# %%
# Convert DataFrame to list
df_list = cleaned_list.values.tolist()

# Print the list
print(df_list)
# Out:
# [[' 2011 5 c 353 bachpan bachao andolan union of india others writ petition no 51 of 2006 april 18 2011 b dalveer bhandari and k patnaik jj child welfare children engaged in circuses protection from physical and sexual abuse held government of india is fully aware about the problems of children working in various places particularly in circuses right of children to free and compulsory education has been made fundamental right under article 21 of the constitution directions given to the central government to issue suitable notifications prohibiting employment of children in circuses within two months further directions issued to conduct simultaneous raids in all the circuses to liberate the children and check the violation of their fundamental rights and to take steps for their rehabilitation the secretary of ministry of human resources development department of women and child development directed to file comprehensive affidavit of compliance court also accepted the submission and re
# ...

# %%
summary_list = summary_list.values.tolist()

# %%
summary_list

# %% [markdown]
# **STEP 2**

# %%
import nltk
nltk.download('punkt')  # Download punkt tokenizer (if not already downloaded)

from nltk.tokenize import sent_tokenize

# Example list of texts
text_list = summary_list

# Split text into sentences using nltk's sent_tokenize function
sentences_list = [sent_tokenize(text) for text in text_list]

# Flatten the nested list of sentences
sentences = [sentence for sublist in sentences_list for sentence in sublist]

# Print the resulting sentences
for sentence in sentences:
    print(sentence)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# Tokenize sentences into words
words_list = [word_tokenize(sentence) for sentence in sentences]

# Flatten the nested list of words
words = [word for sublist in words_list for word in sublist]

# Print the resulting words
for word in words:
    print(word)
# Out:
# Streaming output truncated to the last 5000 lines.
# 370
# 34
# of
# the
# indian
# penal
# code
# and
# section
# 79
# of
# j
# act
# 2015
# no
# 46675
# of
# 2017
# 2
# dt
# 21
# 09
# 2017
# 2
# 2
# having
# heard
# both
# sides
# and
# in
# view
# of
# facts
# and
# circumstances
# let
# petitioner
# above
# named
# be
# released
# on
# bail
# on
# furnishing
# bail
# bond
# of
# rs
# 25
# 000
# rupees
# twenty
# five
# thousand
# with
# two
# sureties
# of
# the
# like
# amount
# each
# to
# the
# satisfaction
# of
# the
# additional
# chief
# judicial
# magistrate
# sherghati
# gaya
# in
# connection
# with
# barachatti
# mohanpur
# s
# case
# no
# 593
# of
# 2014
# subject
# to
# the
# following
# conditions
# 1
# one
# of
# the
# bailors
# shall
# be
# local
# person
# having
# sufficient
# immoveable
# properties
# within
# the
# jurisdiction
# of
# the
# court
# concerned
# 2
# petitioner
# will
# co
# operate
# in
# trial
# and
# appear
# in
# court
# on
# each
# and
# ...

# %%
from collections import Counter

# Example list of words
words_freq = words
# Use Counter to count word occurrences
word_counts = Counter(words)

# Print word counts
for word, count in word_counts.items():
    print(f"{word}: {count} occurrences")
# Out:
# child: 76 occurrences
# welfare: 7 occurrences
# children: 63 occurrences
# engaged: 8 occurrences
# in: 724 occurrences
# circuses: 4 occurrences
# protection: 37 occurrences
# from: 88 occurrences
# physical: 1 occurrences
# and: 1048 occurrences
# sexual: 28 occurrences
# abuse: 4 occurrences
# held: 17 occurrences
# government: 17 occurrences
# of: 1910 occurrences
# india: 13 occurrences
# is: 470 occurrences
# fully: 3 occurrences
# aware: 1 occurrences
# about: 60 occurrences
# the: 3049 occurrences
# problems: 2 occurrences
# working: 6 occurrences
# various: 8 occurrences
# places: 5 occurrences
# particularly: 9 occurrences
# right: 10 occurrences
# to: 688 occurrences
# free: 5 occurrences
# compulsory: 4 occurrences
# education: 13 occurrences
# has: 238 occurrences
# been: 143 occurrences
# made: 66 occurrences
# fundamental: 3 occurrences
# under: 240 occurrences
# article: 9 occurrences
# 21: 18 occurrences
# constitution: 8 occurrences
# directions: 7 occurrences
# ...

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Example list of words
words_freq_1 = words
# Use Counter to count the frequency of each word
word_counts = Counter(words_freq)

# Get the top 10 most common words and their frequencies
top_words = word_counts.most_common(10)
top_words_words = [word[0] for word in top_words]
top_words_counts = [word[1] for word in top_words]

# Create a bar graph of the top 10 word frequencies
plt.bar(top_words_words, top_words_counts)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 30 Word Frequencies')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Example list of words
words_freq_2 = words

# List of words to be removed
words_prep = ["the", "of", "to", "and", "in", "that", "is", "on", "for", 'with', 'mr', 'has', '2', 'as', 'by', 'this', 'be', 'was', '3']

# Filter out words to be removed from the list of words
filtered_words = [word for word in words if word not in words_prep]

# Use Counter to count the frequency of each word
word_counts = Counter(filtered_words)

# Get the top 10 most common words and their frequencies
top_words = word_counts.most_common(20)
top_words_words = [word[0] for word in top_words]
top_words_counts = [word[1] for word in top_words]

# Create a bar graph of the top 10 word frequencies
plt.bar(top_words_words, top_words_counts)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 Word Frequencies (Excluding Words to be Removed)')
plt.xticks(rotation=45)
plt.show()

# %%
words_prep = ["the", "of", "to", "and", "in", "that", "is", "on", "for", 'with', 'mr', 'has', '2', 'as', 'by', 'this', 'be', 'was', '3']

# Iterate over each summary in summary_list
cleaned_summary_list = []
for summary in summary_list:
    # Split summary into words
    words = summary.split()

    # Remove words in words_prep list
    cleaned_words = [word for word in words if word.lower() not in words_prep]

    # Join the cleaned words back to form the cleaned summary
    cleaned_summary = ' '.join(cleaned_words)

    # Add the cleaned summary to cleaned_summary_list
    cleaned_summary_list.append(cleaned_summary)

# %%
cleaned_summary_list

# %%
words_prep = ["the", "of", "to", "and", "in", "that", "is", "on", "for", 'with', 'mr', 'has', '2', 'as', 'by', 'this', 'be', 'was', '3']

# Iterate over each summary in summary_list
cleaned_cleaned_list = []
for summary in summary_list:
    # Split summary into words
    words = summary.split()

    # Remove words in words_prep list
    cleaned_words = [word for word in words if word.lower() not in words_prep]

    # Join the cleaned words back to form the cleaned summary
    cleaned_summary = ' '.join(cleaned_words)

    # Add the cleaned summary to cleaned_summary_list
    cleaned_cleaned_list.append(cleaned_summary)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# Sample documents and summaries
documents = cleaned_cleaned_list
summaries = cleaned_summary_list
# Initialize CountVectorizer object
vectorizer = CountVectorizer()

# Fit and transform the documents and summaries
document_vectors = vectorizer.fit_transform(documents)
summary_vectors = vectorizer.transform(summaries)

# Compute cosine similarity between each document and its corresponding summary
cosine_similarities = cosine_similarity(document_vectors, summary_vectors)

# Print cosine similarity scores and mean similarity score
mean_similarity_score = 0
for i, score in enumerate(cosine_similarities.diagonal()):
    print("Cosine Similarity for Document {}: {:.2f}".format(i+1, score))
    mean_similarity_score += score
mean_similarity_score /= len(cosine_similarities.diagonal())
print("Mean Cosine Similarity: {:.2f}".format(mean_similarity_score))

# %%
#BErtopic

# %%
pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 67.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 69.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.9 MB/s eta 0:00:00
# ...

# %%
#import packages

import pandas as pd
import numpy as np
from bertopic import BERTopic

# %%
# create model

model = BERTopic(verbose=True)


topics, probabilities = model.fit_transform(cleaned_summary_list)
# Out:
# ...
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# 2023-04-23 11:43:48,005 - BERTopic - Transformed documents to Embeddings
# 2023-04-23 11:44:00,368 - BERTopic - Reduced dimensionality
# 2023-04-23 11:44:00,399 - BERTopic - Clustered reduced embeddings

# %%
for i in range(len(topics)):
    print("Summary {}: Topic={}, Probability={}".format(i+1, topics[i], probabilities[i]))
# Out:
# Summary 1: Topic=3, Probability=0.7528859920155231
# Summary 2: Topic=0, Probability=0.9692001762998887
# Summary 3: Topic=0, Probability=0.7203706127358874
# Summary 4: Topic=0, Probability=0.9807985552696024
# Summary 5: Topic=0, Probability=0.9199618033322862
# Summary 6: Topic=-1, Probability=0.0
# Summary 7: Topic=2, Probability=0.603042926174514
# Summary 8: Topic=-1, Probability=0.0
# Summary 9: Topic=-1, Probability=0.0
# Summary 10: Topic=0, Probability=0.9836365894994697
# Summary 11: Topic=-1, Probability=0.0
# Summary 12: Topic=0, Probability=0.9614650132975058
# Summary 13: Topic=1, Probability=0.9453894987311986
# Summary 14: Topic=1, Probability=0.8395622869697723
# Summary 15: Topic=0, Probability=1.0
# Summary 16: Topic=3, Probability=0.71111430890266
# Summary 17: Topic=3, Probability=0.6874114492296989
# Summary 18: Topic=3, Probability=0.7559674756267515
# Summary 19: Topic=-1, Probability=0.0
# Summary 20: Topic=3, Probability=0.6881298362778383
# ...

# %%
model.get_topics()
# Out:
# {-1: [('no', 0.052549511363076916),
#   ('bail', 0.04221800848923531),
#   ('petitioner', 0.040327649900165075),
#   ('order', 0.039263649940331026),
#   ('court', 0.038381063550752596),
#   ('offenders', 0.035109082141753845),
#   ('case', 0.03199975257654686),
#   ('accused', 0.02736819824022967),
#   ('state', 0.025552468177999773),
#   ('learned', 0.02415090933753004)],
#  0: [('applicant', 0.07415899567003652),
#   ('bail', 0.042679904618648457),
#   ('police', 0.03921636177786185),
#   ('no', 0.034932787993549076),
#   ('under', 0.03345465520762339),
#   ('station', 0.030852276876402816),
#   ('case', 0.030030162942276117),
#   ('application', 0.029778806679465898),
#   ('state', 0.028823731472751662),
#   ('court', 0.028309436945235956)],
#  1: [('petitioner', 0.12512280236187875),
#   ('learned', 0.055787790877519096),
#   ('victim', 0.05079045872387474),
#   ('counsel', 0.04501381096577048),
#   ('no', 0.03939371476641999),
#   ('had', 0.03818989144316979),
# ...

# %%
text = cleaned_summary_list

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# we add this to remove stopwords
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english")

model_sum = BERTopic(
    vectorizer_model=vectorizer_model,
    language='english', calculate_probabilities=True,
    verbose=True
)
# Out:
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# 2023-04-24 07:47:39,216 - BERTopic - Transformed documents to Embeddings
# 2023-04-24 07:47:41,964 - BERTopic - Reduced dimensionality
# 2023-04-24 07:47:41,990 - BERTopic - Clustered reduced embeddings

# %%
topics, probs = model_sum.fit_transform(text)
# Out:
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# 2023-04-24 07:49:01,642 - BERTopic - Transformed documents to Embeddings
# 2023-04-24 07:49:08,950 - BERTopic - Reduced dimensionality
# 2023-04-24 07:49:08,973 - BERTopic - Clustered reduced embeddings

# %%
freq = model.get_topic_info()
freq.head(10)
# Out:
#    Topic  Count                                         Name
# 0     -1     46               -1_petitioner_court_order_bail
# 1      0    112              0_applicant_bail_police_station
# 2      1     33              1_petitioner_bail_learned_kumar
# 3      2     30                   2_court_child_petition_act
# 4      3     29  3_petitioner_victim_learned_learned counsel

# %%
freq = model_sum.get_topic_info()
freq.head(10)
# Out:
#    Topic  Count                                         Name
# 0     -1     54             -1_petitioner_bail_learned_court
# 1      0    108              0_applicant_bail_police_station
# 2      1     32              1_petitioner_bail_learned_party
# 3      2     30                   2_court_act_years_petition
# 4      3     26  3_petitioner_victim_learned_learned counsel

# %%
model_sum.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model_sum.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model_sum.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
original = cleaned_cleaned_list

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# we add this to remove stopwords
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english")

model = BERTopic(
    vectorizer_model=vectorizer_model,
    language='english', calculate_probabilities=True,
    verbose=True
)
topics, probs = model.fit_transform(original)
# Out:
# ...
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# 2023-04-24 07:43:59,418 - BERTopic - Transformed documents to Embeddings
# 2023-04-24 07:44:08,052 - BERTopic - Reduced dimensionality
# 2023-04-24 07:44:08,091 - BERTopic - Clustered reduced embeddings

# %%
freq = model.get_topic_info()
freq.head(10)
# Out:
#    Topic  Count                                 Name
# 0     -1     47       -1_petitioner_bail_court_order
# 1      0    114      0_applicant_bail_police_station
# 2      1     33      1_petitioner_bail_learned_kumar
# 3      2     29  2_petitioner_victim_learned_counsel
# 4      3     27           3_court_petition_years_sri

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
